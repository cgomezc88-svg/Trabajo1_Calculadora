# %% [markdown]
# <a href="https://colab.research.google.com/github/cgomezc88-svg/Trabajo1_Calculadora/blob/main/Copia_de_Calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' Calculadora
'''
print("Hola Mundo desde mi iPhone para la calculadora")
# Out:
# Hola Mundo desde mi iPhone para la calculadora
